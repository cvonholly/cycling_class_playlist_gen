# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from src.get_token import client_id, client_secret

birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id, client_secret))

results = sp.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = sp.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Portraits (+ Remixes)
# Portraits
# Young Heart
# Beautiful Lies (Deluxe)
# Fire Within (Deluxe)
# Live in London
# Birdy (Deluxe Version)
# Birdy

# %%
[playlist_items['items'][i]['track']['name'] for i in range(len(playlist_items['items']))]
# Out:
# ['Bicycle Race - Remastered 2011',
#  'Blessed',
#  'Neon',
#  'Du weißt (feat. KitschKrieg) - Remix',
#  'Ufe',
#  'Alles OK',
#  'Ide Strass (feat. Phenomden)',
#  'Ziitreis',
#  'Publibike',
#  'Fast Life',
#  'Saurus',
#  'Das Letzte - Live',
#  'Generation YouPorn',
#  'Bike Rider',
#  'La bicyclette',
#  'Faster You Fall',
#  'Pepas',
#  'Alors on danse - Radio Edit',
#  'Sweet Dreams (Are Made of This) - Remastered',
#  'Daddy Cool',
#  'September',
#  'Big in Japan - 2019 Remaster',
#  'Gimme! Gimme! Gimme! (A Man After Midnight)',
#  'Rasputin',
#  'Dancing Queen',
#  'Sunny',
#  'Voyage voyage',
#  'Boogie Wonderland',
#  'Junge',
#  "Mutter, der Mann mit dem Koks ist da - Mother's Favourite",
#  'Zeig deine Muskeln',
#  'Artig',
#  'Seven Nation Army',
#  'Where Is My Mind? - Remastered',
#  'YMCA',
#  'Narcotic - Radio Edit',
#  'Junge Roemer',
#  'Fahrrad fahr´n',
#  '99 Luftballons',
#  'Major Tom (...völlig losgelöst)',
#  'Skandal im Sperrbezirk',
#  'Codo (...düse im Sauseschritt)',
#  '36Grad',
#  'Love On The Rocks',
#  'Never Going Home',
#  'Perreito',
#  'Eisbär',
#  'Giro',
#  'Jan Ullrich',
#  'Unten kommt die Gurke rein',
#  'Licht am Fahrrad',
#  'Nie wieder - Palma de Mallorca Edit',
#  '8000watt',
#  "Ja, mir san mit'm Radl da",
#  'Griechischer Wein',
#  'Zeit steht',
#  'Sk8er Boi']

# %%
track_id = "1gpILkbKweZCqMCdX8bsvL"
audio_info = sp.audio_analysis(track_id)
#print(audio_info)

audio_features = sp.audio_features(track_id) # or list of track_ids
#print(audio_features)

playlist_id = "52wWctsy8K6i2kePj7VGHc"
playlist_url = "https://open.spotify.com/playlist/52wWctsy8K6i2kePj7VGHc?si=3757e3cde9eb48c0"
techno_playlist = "https://open.spotify.com/playlist/37i9dQZF1DX6J5NfMJS675?si=aca32942f2b44c15"
playlist = sp.playlist(playlist_id) # , fields=?
playlist_items = sp.playlist_items(playlist_id)
playlist_tracks = sp.playlist_tracks(playlist_url) # playlist ID, URI or URL

print(playlist_tracks['items'][0]['track']['id'])
print(playlist_tracks['items'][0]['track']['track'])

techno_playlist = sp.playlist_tracks(techno_playlist)

song_ids = [track['track']['id'] for track in techno_playlist['items']]

techno_audio_features = sp.audio_features(song_ids)
#print(techno_audio_features)
for song in techno_audio_features:
    audio_info = sp.audio_analysis(song['id'])
    print(song['tempo'])
    print(audio_info['track']['tempo_confidence'])
# Out:
# 5CTAcf8aS0a0sIsDwQRF9C
# True
# 139.993
# 0.795
# 139.985
# 0.744
# 137.014
# 0.953
# 160.024
# 0.762
# 155.946
# 0.802
# 144.981
# 0.938
# 139.963
# 0.631
# 137.999
# 0.763
# 138.012
# 0.771
# 135.994
# 0.935
# 134.994
# 0.95
# 135.004
# 0.885
# 138.014
# 0.94
# 135.973
# 0.885
# 134.001
# 0.766
# 133.987
# 0.976
# 133.982
# 0.801
# 136.987
# 0.858
# 135.005
# 0.934
# 134.979
# 0.838
# 132.018
# 0.793
# 132.98
# 0.82
# 128.012
# 0.946
# 131.991
# 0.802
# 129.999
# 0.815
# 132.004
# 0.861
# 132.031
# 0.817
# 153.021
# 0.985
# 138.008
# 0.868
# 138.008
# 0.859
# 134.951
# 0.908
# 134.978
# 0.979
# 133.987
# 1.0
# 133.982
# 0.842
# 131.994
# 0.886
# 135.018
# 1.0
# 139.987
# 0.876
# 138.002
# 0.536
# 139.987
# 0.753
# 144.001
# 0.761
# 145.012
# 1.0
# 150.035
# 0.622
# 155.004
# 0.875
# 155.017
# 0.798
# 145.007
# 0.892
# 135.013
# 0.919
# 133.006
# 0.915
# 133.988
# 0.933
# 135.993
# 0.935
# 130.003
# 0.886
# 131.989
# 0.816
# 129.997
# 0.815
# 134.982
# 0.925
# 136.01
# 0.903
# 149.989
# 0.422
# 135.998
# 0.829
# 133.013
# 0.861
# 133.991
# 0.831
# 131.978
# 0.756
# 128.993
# 0.704

# %%
from __future__ import print_function
import sys
import spotipy
import spotipy.util as util

scope = 'user-library-read'

if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Usage: %s username" % (sys.argv[0],))
    sys.exit()

token = util.prompt_for_user_token(username, scope,
                                   client_id=client_id,
                                   client_secret=client_secret,
                                   redirect_uri='http://localhost:3000')

if token:
    sp = spotipy.Spotify(auth=token)
    results = sp.current_user_saved_tracks()
    for item in results['items']:
        track = item['track']
        print(track['name'] + ' - ' + track['artists'][0]['name'])
else:
    print("Can't get token for", username)
# Out:
# Couldn't read cache at: .cache---f=c:\Users\carlv\AppData\Roaming\jupyter\runtime\kernel-v2-24464cvCVTF28Uydm.json
# Couldn't read cache at: .cache---f=c:\Users\carlv\AppData\Roaming\jupyter\runtime\kernel-v2-24464cvCVTF28Uydm.json
# Couldn't write token to cache at: .cache---f=c:\Users\carlv\AppData\Roaming\jupyter\runtime\kernel-v2-24464cvCVTF28Uydm.json
# Symphonische Etüden, Op. 13: Anhang Variation 1 - Robert Schumann
# Universo - Original mix - Astrix
# Exist - Katia Val
# Barber's Adagio for Strings - Ferry Corsten Remix; Radio Edit; - William Orbit
# 1882 - Daniel Skyver
# Midnight Sun - IanT
# Applause - Live From Philharmonie, Berlin / 2001 - Various Artists
# Scriabin: 24 Preludes, Op. 11: No. 16 in B-Flat Minor - Alexander Scriabin
# You & Me - Flume Remix - Disclosure
# Piano Sonata in B minor, S.178 - Franz Liszt
# D'un soir triste - Lili Boulanger
# Adelaide, S. 466 (After Beethoven's Op. 46) - Franz Liszt
# Tosca / Act II: "Vissi d'arte, vissi d'amore" - Giacomo Puccini
# Tosca / Act I: "Un tal baccano in chiesa! Bel rispetto!" - Giacomo Puccini
# Symphony No. 2 in C, Op. 61: 3. Adagio espresssivo - Robert Schumann
# Tosca / Act I: "Ah! Finalmente!" - Giacomo Puccini
# Toccata and Fugue in D minor - Johann Sebastian Bach
# Tosca / Act III: "E lucevan le stelle" - Giacomo Puccini
# Poetry - Edit - Stella Bossi
# Symphony No. 7 in C Major, Op. 60, "Leningrad": IV. Allegro non troppo - Dmitri Shostakovich

# %%
import pandas as pd
dic = sp.current_user_playlists(limit=20)
playlist_names = [x['name'] for x in dic['items']]
[x['external_urls']['spotify'] for x in dic['items']]
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/2TqES4i0yRR6sLVNhiEyPs'},
#  'href': 'https://api.spotify.com/v1/playlists/2TqES4i0yRR6sLVNhiEyPs',
#  'id': '2TqES4i0yRR6sLVNhiEyPs',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b27327ce0e73b9cf23e8e22ebfe4',
#    'width': 640}],
#  'name': 'Moderat',
#  'owner': {'display_name': 'carlvonholly',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/carlvonholly'},
#   'href': 'https://api.spotify.com/v1/users/carlvonholly',
#   'id': 'carlvonholly',
#   'type': 'user',
#   'uri': 'spotify:user:carlvonholly'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'Miw4NjAzNmYwMjE2OWFkYTRlYWFjZmZiNTljMWZhYzI3MGJjNjQzMjE3',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/2TqES4i0yRR6sLVNhiEyPs/tracks',
#   'total': 15},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:2TqES4i0yRR6sLVNhiEyPs'}

# %%
playlist_tracks
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/52wWctsy8K6i2kePj7VGHc/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2022-07-28T20:11:44Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jhearsmusic'},
#     'href': 'https://api.spotify.com/v1/users/jhearsmusic',
#     'id': 'jhearsmusic',
#     'type': 'user',
#     'uri': 'spotify:user:jhearsmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#        'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#        'id': '1dfeR4HaWDbWqFHLkxsg1d',
#        'name': 'Queen',
#        'type': 'artist',
#        'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2yuTRGIackbcReLUXOYBqU'},
#      'href': 'https://api.spotify.com/v1/albums/2yuTRGIackbcReLUXOYBqU',
#      'id': '2yuTRGIackbcReLUXOYBqU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737c39dd133836c2c1c87e34d6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027c39dd133836c2c1c87e34d6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517c39dd133836c2c1c87e34d6',
#        'width': 64}],
#      'name': 'Jazz (2011 Remaster)',
#      'release_date': '1978-11-10',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2yuTRGIackbcReLUXOYBqU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#       'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#       'id': '1dfeR4HaWDbWqFHLkxsg1d',
#       'name': 'Queen',
#       'type': 'artist',
#       'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 180813,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71029608'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5CTAcf8aS0a0sIsDwQRF9C'},
#     'href': 'https://api.spotify.com/v1/tracks/5CTAcf8aS0a0sIsDwQRF9C',
#     'id': '5CTAcf8aS0a0sIsDwQRF9C',
#     'is_local': False,
#     'name': 'Bicycle Race - Remastered 2011',
#     'popularity': 63,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5CTAcf8aS0a0sIsDwQRF9C'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-07-28T21:24:38Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jhearsmusic'},
#     'href': 'https://api.spotify.com/v1/users/jhearsmusic',
#     'id': 'jhearsmusic',
#     'type': 'user',
#     'uri': 'spotify:user:jhearsmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#        'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#        'id': '5FK3qokBQYxr7ZLkr8GVFn',
#        'name': 'Stereo Luchs',
#        'type': 'artist',
#        'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2z3jR0VMDeFaw547iNMbyG'},
#      'href': 'https://api.spotify.com/v1/albums/2z3jR0VMDeFaw547iNMbyG',
#      'id': '2z3jR0VMDeFaw547iNMbyG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739ef0323b1096481e3989cf7c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029ef0323b1096481e3989cf7c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519ef0323b1096481e3989cf7c',
#        'width': 64}],
#      'name': 'Stereo Luchs',
#      'release_date': '2021-12-03',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2z3jR0VMDeFaw547iNMbyG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#       'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#       'id': '5FK3qokBQYxr7ZLkr8GVFn',
#       'name': 'Stereo Luchs',
#       'type': 'artist',
#       'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 131226,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CHUM72100219'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6STsyoUdL8V9Kxe6j1lJYI'},
#     'href': 'https://api.spotify.com/v1/tracks/6STsyoUdL8V9Kxe6j1lJYI',
#     'id': '6STsyoUdL8V9Kxe6j1lJYI',
#     'is_local': False,
#     'name': 'Blessed',
#     'popularity': 33,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6STsyoUdL8V9Kxe6j1lJYI'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-07-29T08:11:13Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jhearsmusic'},
#     'href': 'https://api.spotify.com/v1/users/jhearsmusic',
#     'id': 'jhearsmusic',
#     'type': 'user',
#     'uri': 'spotify:user:jhearsmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#        'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#        'id': '5FK3qokBQYxr7ZLkr8GVFn',
#        'name': 'Stereo Luchs',
#        'type': 'artist',
#        'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2z3jR0VMDeFaw547iNMbyG'},
#      'href': 'https://api.spotify.com/v1/albums/2z3jR0VMDeFaw547iNMbyG',
#      'id': '2z3jR0VMDeFaw547iNMbyG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739ef0323b1096481e3989cf7c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029ef0323b1096481e3989cf7c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519ef0323b1096481e3989cf7c',
#        'width': 64}],
#      'name': 'Stereo Luchs',
#      'release_date': '2021-12-03',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2z3jR0VMDeFaw547iNMbyG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#       'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#       'id': '5FK3qokBQYxr7ZLkr8GVFn',
#       'name': 'Stereo Luchs',
#       'type': 'artist',
#       'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 179333,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CHUM72100225'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/11UxE6Gk0A723V5L2yJMF8'},
#     'href': 'https://api.spotify.com/v1/tracks/11UxE6Gk0A723V5L2yJMF8',
#     'id': '11UxE6Gk0A723V5L2yJMF8',
#     'is_local': False,
#     'name': 'Neon',
#     'popularity': 21,
#     'preview_url': None,
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:11UxE6Gk0A723V5L2yJMF8'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-07-29T07:49:24Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jhearsmusic'},
#     'href': 'https://api.spotify.com/v1/users/jhearsmusic',
#     'id': 'jhearsmusic',
#     'type': 'user',
#     'uri': 'spotify:user:jhearsmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6QzzeKV0VcnT2vJMYDPuL4'},
#        'href': 'https://api.spotify.com/v1/artists/6QzzeKV0VcnT2vJMYDPuL4',
#        'id': '6QzzeKV0VcnT2vJMYDPuL4',
#        'name': 'Trettmann',
#        'type': 'artist',
#        'uri': 'spotify:artist:6QzzeKV0VcnT2vJMYDPuL4'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#        'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#        'id': '5FK3qokBQYxr7ZLkr8GVFn',
#        'name': 'Stereo Luchs',
#        'type': 'artist',
#        'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ZT8zCu4xXbz7R1R0EzqWO'},
#        'href': 'https://api.spotify.com/v1/artists/2ZT8zCu4xXbz7R1R0EzqWO',
#        'id': '2ZT8zCu4xXbz7R1R0EzqWO',
#        'name': 'Pronto',
#        'type': 'artist',
#        'uri': 'spotify:artist:2ZT8zCu4xXbz7R1R0EzqWO'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4gmzbsJy5KumWjtLqYuom3'},
#      'href': 'https://api.spotify.com/v1/albums/4gmzbsJy5KumWjtLqYuom3',
#      'id': '4gmzbsJy5KumWjtLqYuom3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c2cd64e4d91a2d72dbf6b439',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c2cd64e4d91a2d72dbf6b439',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c2cd64e4d91a2d72dbf6b439',
#        'width': 64}],
#      'name': 'Du weißt (feat. KitschKrieg) [Remix]',
#      'release_date': '2019-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4gmzbsJy5KumWjtLqYuom3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6QzzeKV0VcnT2vJMYDPuL4'},
#       'href': 'https://api.spotify.com/v1/artists/6QzzeKV0VcnT2vJMYDPuL4',
#       'id': '6QzzeKV0VcnT2vJMYDPuL4',
#       'name': 'Trettmann',
#       'type': 'artist',
#       'uri': 'spotify:artist:6QzzeKV0VcnT2vJMYDPuL4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#       'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#       'id': '5FK3qokBQYxr7ZLkr8GVFn',
#       'name': 'Stereo Luchs',
#       'type': 'artist',
#       'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ZT8zCu4xXbz7R1R0EzqWO'},
#       'href': 'https://api.spotify.com/v1/artists/2ZT8zCu4xXbz7R1R0EzqWO',
#       'id': '2ZT8zCu4xXbz7R1R0EzqWO',
#       'name': 'Pronto',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ZT8zCu4xXbz7R1R0EzqWO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5tHiL8SKSaZGMBUPIiSmX4'},
#       'href': 'https://api.spotify.com/v1/artists/5tHiL8SKSaZGMBUPIiSmX4',
#       'id': '5tHiL8SKSaZGMBUPIiSmX4',
#       'name': 'KitschKrieg',
#       'type': 'artist',
#       'uri': 'spotify:artist:5tHiL8SKSaZGMBUPIiSmX4'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 190434,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DELV41900669'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/68mJ67zAIXTygZYutyuNHo'},
#     'href': 'https://api.spotify.com/v1/tracks/68mJ67zAIXTygZYutyuNHo',
#     'id': '68mJ67zAIXTygZYutyuNHo',
#     'is_local': False,
#     'name': 'Du weißt (feat. KitschKrieg) - Remix',
#     'popularity': 24,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:68mJ67zAIXTygZYutyuNHo'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-07-28T20:11:48Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jhearsmusic'},
#     'href': 'https://api.spotify.com/v1/users/jhearsmusic',
#     'id': 'jhearsmusic',
#     'type': 'user',
#     'uri': 'spotify:user:jhearsmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#        'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#        'id': '5FK3qokBQYxr7ZLkr8GVFn',
#        'name': 'Stereo Luchs',
#        'type': 'artist',
#        'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3jr3SiQStPaOlBZwEgbPfg'},
#      'href': 'https://api.spotify.com/v1/albums/3jr3SiQStPaOlBZwEgbPfg',
#      'id': '3jr3SiQStPaOlBZwEgbPfg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dbef6d76eded9a8678bc33f8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dbef6d76eded9a8678bc33f8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dbef6d76eded9a8678bc33f8',
#        'width': 64}],
#      'name': 'LINCE',
#      'release_date': '2017-10-20',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3jr3SiQStPaOlBZwEgbPfg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#       'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#       'id': '5FK3qokBQYxr7ZLkr8GVFn',
#       'name': 'Stereo Luchs',
#       'type': 'artist',
#       'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ZT8zCu4xXbz7R1R0EzqWO'},
#       'href': 'https://api.spotify.com/v1/artists/2ZT8zCu4xXbz7R1R0EzqWO',
#       'id': '2ZT8zCu4xXbz7R1R0EzqWO',
#       'name': 'Pronto',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ZT8zCu4xXbz7R1R0EzqWO'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 227040,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CHUM71700276'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5dkUBm3J7EUYvcVnyTy3eN'},
#     'href': 'https://api.spotify.com/v1/tracks/5dkUBm3J7EUYvcVnyTy3eN',
#     'id': '5dkUBm3J7EUYvcVnyTy3eN',
#     'is_local': False,
#     'name': 'Ufe',
#     'popularity': 33,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5dkUBm3J7EUYvcVnyTy3eN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-08-12T15:25:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jhearsmusic'},
#     'href': 'https://api.spotify.com/v1/users/jhearsmusic',
#     'id': 'jhearsmusic',
#     'type': 'user',
#     'uri': 'spotify:user:jhearsmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#        'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#        'id': '5FK3qokBQYxr7ZLkr8GVFn',
#        'name': 'Stereo Luchs',
#        'type': 'artist',
#        'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3jr3SiQStPaOlBZwEgbPfg'},
#      'href': 'https://api.spotify.com/v1/albums/3jr3SiQStPaOlBZwEgbPfg',
#      'id': '3jr3SiQStPaOlBZwEgbPfg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dbef6d76eded9a8678bc33f8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dbef6d76eded9a8678bc33f8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dbef6d76eded9a8678bc33f8',
#        'width': 64}],
#      'name': 'LINCE',
#      'release_date': '2017-10-20',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3jr3SiQStPaOlBZwEgbPfg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#       'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#       'id': '5FK3qokBQYxr7ZLkr8GVFn',
#       'name': 'Stereo Luchs',
#       'type': 'artist',
#       'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6QzzeKV0VcnT2vJMYDPuL4'},
#       'href': 'https://api.spotify.com/v1/artists/6QzzeKV0VcnT2vJMYDPuL4',
#       'id': '6QzzeKV0VcnT2vJMYDPuL4',
#       'name': 'Trettmann',
#       'type': 'artist',
#       'uri': 'spotify:artist:6QzzeKV0VcnT2vJMYDPuL4'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 186666,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CHUM71700289'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2R6q4npe17MVWrAfJtscY1'},
#     'href': 'https://api.spotify.com/v1/tracks/2R6q4npe17MVWrAfJtscY1',
#     'id': '2R6q4npe17MVWrAfJtscY1',
#     'is_local': False,
#     'name': 'Alles OK',
#     'popularity': 22,
#     'preview_url': None,
#     'track': True,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:2R6q4npe17MVWrAfJtscY1'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-07-28T20:21:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jhearsmusic'},
#     'href': 'https://api.spotify.com/v1/users/jhearsmusic',
#     'id': 'jhearsmusic',
#     'type': 'user',
#     'uri': 'spotify:user:jhearsmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#        'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#        'id': '5FK3qokBQYxr7ZLkr8GVFn',
#        'name': 'Stereo Luchs',
#        'type': 'artist',
#        'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2z3jR0VMDeFaw547iNMbyG'},
#      'href': 'https://api.spotify.com/v1/albums/2z3jR0VMDeFaw547iNMbyG',
#      'id': '2z3jR0VMDeFaw547iNMbyG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739ef0323b1096481e3989cf7c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029ef0323b1096481e3989cf7c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519ef0323b1096481e3989cf7c',
#        'width': 64}],
#      'name': 'Stereo Luchs',
#      'release_date': '2021-12-03',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:2z3jR0VMDeFaw547iNMbyG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#       'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#       'id': '5FK3qokBQYxr7ZLkr8GVFn',
#       'name': 'Stereo Luchs',
#       'type': 'artist',
#       'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0I8Fhlo5rqJCj7iVrJGXC4'},
#       'href': 'https://api.spotify.com/v1/artists/0I8Fhlo5rqJCj7iVrJGXC4',
#       'id': '0I8Fhlo5rqJCj7iVrJGXC4',
#       'name': 'Phenomden',
#       'type': 'artist',
#       'uri': 'spotify:artist:0I8Fhlo5rqJCj7iVrJGXC4'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 210560,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CHUM72100072'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5jA4o05TP6ycqDiRJ7js7K'},
#     'href': 'https://api.spotify.com/v1/tracks/5jA4o05TP6ycqDiRJ7js7K',
#     'id': '5jA4o05TP6ycqDiRJ7js7K',
#     'is_local': False,
#     'name': 'Ide Strass (feat. Phenomden)',
#     'popularity': 36,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5jA4o05TP6ycqDiRJ7js7K'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-07-28T20:11:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jhearsmusic'},
#     'href': 'https://api.spotify.com/v1/users/jhearsmusic',
#     'id': 'jhearsmusic',
#     'type': 'user',
#     'uri': 'spotify:user:jhearsmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FK3qokBQYxr7ZLkr8GVFn'},
#        'href': 'https://api.spotify.com/v1/artists/5FK3qokBQYxr7ZLkr8GVFn',
#        'id': '5FK3qokBQYxr7ZLkr8GVFn',
#        'name': 'Stereo Luchs',
#        'type': 'artist',
#        'uri': 'spotify:artist:5FK3qokBQYxr7ZLkr8GVFn'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
# ...
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/56ai76GnHunah8IjNeP8IR'},
#      'href': 'https://api.spotify.com/v1/albums/56ai76GnHunah8IjNeP8IR',
#      'id': '56ai76GnHunah8IjNeP8IR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27386f8b7ae69137fea4479cbf3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0286f8b7ae69137fea4479cbf3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485186f8b7ae69137fea4479cbf3',
#        'width': 64}],
#      'name': 'Meine Lieder',
#      'release_date': '1983-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:56ai76GnHunah8IjNeP8IR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G0htB8PxlO2onxnIismur'},
#       'href': 'https://api.spotify.com/v1/artists/2G0htB8PxlO2onxnIismur',
#       'id': '2G0htB8PxlO2onxnIismur',
#       'name': 'Udo Jürgens',
#       'type': 'artist',
#       'uri': 'spotify:artist:2G0htB8PxlO2onxnIismur'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 244693,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEA817400019'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2f8Hc0w7BpDtzwoa6BHKec'},
#     'href': 'https://api.spotify.com/v1/tracks/2f8Hc0w7BpDtzwoa6BHKec',
#     'id': '2f8Hc0w7BpDtzwoa6BHKec',
#     'is_local': False,
#     'name': 'Griechischer Wein',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/83c99c0fa028bb3dd6b3c494bddc2a1bd2cb17ff?cid=54cfccda4e9943e5a50fcbe7fe29b695',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2f8Hc0w7BpDtzwoa6BHKec'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-07-29T08:12:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jhearsmusic'},
#     'href': 'https://api.spotify.com/v1/users/jhearsmusic',
#     'id': 'jhearsmusic',
#     'type': 'user',
#     'uri': 'spotify:user:jhearsmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6QzzeKV0VcnT2vJMYDPuL4'},
#        'href': 'https://api.spotify.com/v1/artists/6QzzeKV0VcnT2vJMYDPuL4',
#        'id': '6QzzeKV0VcnT2vJMYDPuL4',
#        'name': 'Trettmann',
#        'type': 'artist',
#        'uri': 'spotify:artist:6QzzeKV0VcnT2vJMYDPuL4'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5tHiL8SKSaZGMBUPIiSmX4'},
#        'href': 'https://api.spotify.com/v1/artists/5tHiL8SKSaZGMBUPIiSmX4',
#        'id': '5tHiL8SKSaZGMBUPIiSmX4',
#        'name': 'KitschKrieg',
#        'type': 'artist',
#        'uri': 'spotify:artist:5tHiL8SKSaZGMBUPIiSmX4'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/53EHeXzGs4HheTCTnwfPEr'},
#        'href': 'https://api.spotify.com/v1/artists/53EHeXzGs4HheTCTnwfPEr',
#        'id': '53EHeXzGs4HheTCTnwfPEr',
#        'name': 'SFR',
#        'type': 'artist',
#        'uri': 'spotify:artist:53EHeXzGs4HheTCTnwfPEr'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6nNWkAwlHC0yIoKzzl7rnQ'},
#      'href': 'https://api.spotify.com/v1/albums/6nNWkAwlHC0yIoKzzl7rnQ',
#      'id': '6nNWkAwlHC0yIoKzzl7rnQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27379673047e0159ded94c03725',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0279673047e0159ded94c03725',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485179673047e0159ded94c03725',
#        'width': 64}],
#      'name': 'Trettmann',
#      'release_date': '2019-09-13',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6nNWkAwlHC0yIoKzzl7rnQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6QzzeKV0VcnT2vJMYDPuL4'},
#       'href': 'https://api.spotify.com/v1/artists/6QzzeKV0VcnT2vJMYDPuL4',
#       'id': '6QzzeKV0VcnT2vJMYDPuL4',
#       'name': 'Trettmann',
#       'type': 'artist',
#       'uri': 'spotify:artist:6QzzeKV0VcnT2vJMYDPuL4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5tHiL8SKSaZGMBUPIiSmX4'},
#       'href': 'https://api.spotify.com/v1/artists/5tHiL8SKSaZGMBUPIiSmX4',
#       'id': '5tHiL8SKSaZGMBUPIiSmX4',
#       'name': 'KitschKrieg',
#       'type': 'artist',
#       'uri': 'spotify:artist:5tHiL8SKSaZGMBUPIiSmX4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2fUZ5QodNiQntWefUy6Jfh'},
#       'href': 'https://api.spotify.com/v1/artists/2fUZ5QodNiQntWefUy6Jfh',
#       'id': '2fUZ5QodNiQntWefUy6Jfh',
#       'name': 'Alli Neumann',
#       'type': 'artist',
#       'uri': 'spotify:artist:2fUZ5QodNiQntWefUy6Jfh'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/53EHeXzGs4HheTCTnwfPEr'},
#       'href': 'https://api.spotify.com/v1/artists/53EHeXzGs4HheTCTnwfPEr',
#       'id': '53EHeXzGs4HheTCTnwfPEr',
#       'name': 'SFR',
#       'type': 'artist',
#       'uri': 'spotify:artist:53EHeXzGs4HheTCTnwfPEr'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 203173,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DELV41900368'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/22ET3BvBsXcGiwxy1uXPbU'},
#     'href': 'https://api.spotify.com/v1/tracks/22ET3BvBsXcGiwxy1uXPbU',
#     'id': '22ET3BvBsXcGiwxy1uXPbU',
#     'is_local': False,
#     'name': 'Zeit steht',
#     'popularity': 51,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:22ET3BvBsXcGiwxy1uXPbU'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-08-02T09:59:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jhearsmusic'},
#     'href': 'https://api.spotify.com/v1/users/jhearsmusic',
#     'id': 'jhearsmusic',
#     'type': 'user',
#     'uri': 'spotify:user:jhearsmusic'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4nmQO2msCgU4IF37Wi3j'},
#        'href': 'https://api.spotify.com/v1/artists/0p4nmQO2msCgU4IF37Wi3j',
#        'id': '0p4nmQO2msCgU4IF37Wi3j',
#        'name': 'Avril Lavigne',
#        'type': 'artist',
#        'uri': 'spotify:artist:0p4nmQO2msCgU4IF37Wi3j'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3zXjR3y2dUWklKmmp6lEhy'},
#      'href': 'https://api.spotify.com/v1/albums/3zXjR3y2dUWklKmmp6lEhy',
#      'id': '3zXjR3y2dUWklKmmp6lEhy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f7ec724fbf97a30869d06240',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f7ec724fbf97a30869d06240',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f7ec724fbf97a30869d06240',
#        'width': 64}],
#      'name': 'Let Go',
#      'release_date': '2002-06-04',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:3zXjR3y2dUWklKmmp6lEhy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4nmQO2msCgU4IF37Wi3j'},
#       'href': 'https://api.spotify.com/v1/artists/0p4nmQO2msCgU4IF37Wi3j',
#       'id': '0p4nmQO2msCgU4IF37Wi3j',
#       'name': 'Avril Lavigne',
#       'type': 'artist',
#       'uri': 'spotify:artist:0p4nmQO2msCgU4IF37Wi3j'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 204000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAR10200229'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/00Mb3DuaIH1kjrwOku9CGU'},
#     'href': 'https://api.spotify.com/v1/tracks/00Mb3DuaIH1kjrwOku9CGU',
#     'id': '00Mb3DuaIH1kjrwOku9CGU',
#     'is_local': False,
#     'name': 'Sk8er Boi',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7891901b2270cc8ef724f64db5bb97be081329d6?cid=54cfccda4e9943e5a50fcbe7fe29b695',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:00Mb3DuaIH1kjrwOku9CGU'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 57}
